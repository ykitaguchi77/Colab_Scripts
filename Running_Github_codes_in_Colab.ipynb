# %% [markdown]
# <a href="https://colab.research.google.com/github/ykitaguchi77/Colab_Scripts/blob/master/Running_Github_codes_in_Colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Running Github codes in Google Colab

# %%
#Githubよりリポジトリをcloneする
# !git clone https://github.com/pytorch/examples.git
# Out:
# Cloning into 'examples'...
# remote: Enumerating objects: 20, done.
# remote: Counting objects: 100% (20/20), done.
# remote: Compressing objects: 100% (18/18), done.
# remote: Total 2333 (delta 3), reused 11 (delta 1), pack-reused 2313
# Receiving objects: 100% (2333/2333), 39.03 MiB | 18.26 MiB/s, done.
# Resolving deltas: 100% (1166/1166), done.

# %% [markdown]
# #作業ディレクトリを移動

# %%
import os
path = '/content/examples/mnist'

#作業ディレクトリをpathに移動する
os.chdir(path)

#作業ディレクトリ直下のファイルを確認
# !ls
# Out:
# main.py  README.md  requirements.txt

# %% [markdown]
# #Pythonファイルを実行する

# %%
# !python3 main.py
# Out:
# ...
# 9920512it [00:01, 8826382.89it/s]
# Extracting ../data/MNIST/raw/train-images-idx3-ubyte.gz to ../data/MNIST/raw
# ...
# 32768it [00:00, 116559.92it/s]
# Extracting ../data/MNIST/raw/train-labels-idx1-ubyte.gz to ../data/MNIST/raw
# ...
# 1654784it [00:00, 2323406.96it/s]
# Extracting ../data/MNIST/raw/t10k-images-idx3-ubyte.gz to ../data/MNIST/raw
# ...
# 8192it [00:00, 42314.43it/s]
# Extracting ../data/MNIST/raw/t10k-labels-idx1-ubyte.gz to ../data/MNIST/raw
# Processing...
# Done!
# Train Epoch: 1 [0/60000 (0%)]	Loss: 2.333409
# Train Epoch: 1 [640/60000 (1%)]	Loss: 1.268057
# Train Epoch: 1 [1280/60000 (2%)]	Loss: 0.859085
# Train Epoch: 1 [1920/60000 (3%)]	Loss: 0.609946
# Train Epoch: 1 [2560/60000 (4%)]	Loss: 0.394730
# Train Epoch: 1 [3200/60000 (5%)]	Loss: 0.440521
# Train Epoch: 1 [3840/60000 (6%)]	Loss: 0.293541
# Train Epoch: 1 [4480/60000 (7%)]	Loss: 0.194774
# Train Epoch: 1 [5120/60000 (9%)]	Loss: 0.463999
# Train Epoch: 1 [5760/60000 (10%)]	Loss: 0.245144
# ...
