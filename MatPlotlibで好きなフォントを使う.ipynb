# %% [markdown]
# <a href="https://colab.research.google.com/github/ykitaguchi77/Colab_Scripts/blob/master/MatPlotlib%E3%81%A7%E5%A5%BD%E3%81%8D%E3%81%AA%E3%83%95%E3%82%A9%E3%83%B3%E3%83%88%E3%82%92%E4%BD%BF%E3%81%86.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**MatPlotlibで自由なフォントを使用する**
# 準備： gdrive内にフォントのフォルダを作っておき、その中にttfファイルをダウンロードしておく

# %% [markdown]
# ![folder.png](data:image/png;base64,...)

# %%
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm
import glob

from google.colab import drive
drive.mount("/content/gdrive")

print("")
print(glob.glob("/content/gdrive/MyDrive/Font/*"))
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).
#
# ['/content/gdrive/MyDrive/Font/arial.ttf', '/content/gdrive/MyDrive/Font/Helvetica.ttf', '/content/gdrive/MyDrive/Font/cinecaption226.ttf']

# %%
import matplotlib.font_manager as fm

FONT_PATH = '/content/gdrive/MyDrive/Font/cinecaption226.ttf'
fp = fm.FontProperties(fname=FONT_PATH)

print(fp.get_name())
print(fp.get_family())

plt.rcParams["font.family"] = fp.get_family()


plt.rcParams["font.size"] = 30
plt.title('Raspberry Pi', fontproperties=fp)
plt.ylabel('aaa', fontproperties=fp)


#解像度を上げてセーブする
plt.savefig("/content/default_dpi.png", bbox_inches="tight", pad_inches=0.05, format="png")
plt.savefig("/content/300_dpi.png", bbox_inches="tight", pad_inches=0.05, format="png", dpi=300)
# Out:
# cinecaption
# ['sans-serif']
