# %% [markdown]
# <a href="https://colab.research.google.com/github/ykitaguchi77/Colab_Scripts/blob/master/%E3%83%95%E3%82%A9%E3%83%AB%E3%83%80%E5%86%85%E3%81%AE%E7%94%BB%E5%83%8F%E3%82%92%E4%B8%80%E9%83%A8%E3%82%B3%E3%83%94%E3%83%BC.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**フォルダ内の画像を一部コピーする**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
orig_path = "/content/drive/MyDrive/Deep_learning/eyelid_images/out2"
#dst_path = "/content/dst_folder"
dst_path = "/content/drive/MyDrive/Deep_learning/eyelid_images/川崎先生"
num = 500  #コピーする画像の枚数

# %%
import shutil
import glob
import os

files = os.listdir(orig_path)[0:num]
print(files)

os.makedirs(dst_path, exist_ok=True)

k=0
for i in files:
    shutil.copy(orig_path + "/" +i, dst_path + "/" + i)
    k+=1
    print(str(k)+"/"+str(num)+" files copied")
# Out:
# ['73-1-0.jpg', '73-2-1.jpg', '72-1-0.jpg', '72-1-1.jpg', '72-2-1.jpg', '72-2-0.jpg', '72-3-0.jpg', '72-3-1.jpg', '72-4-0.jpg', '72-4-1.jpg', '72-5-1.jpg', '72-5-0.jpg', '72-6-0.jpg', '72-6-1.jpg', '72-7-0.jpg', '72-7-1.jpg', '72-8-1.jpg', '72-8-0.jpg', '72-9-0.jpg', '72-9-1.jpg', '72-10-0.jpg', '72-10-1.jpg', '72-11-0.jpg', '72-11-1.jpg', '78-1-1.jpg', '78-2-0.jpg', '78-2-1.jpg', '78-3-1.jpg', '78-4-1.jpg', '78-4-0.jpg', '78-5-0.jpg', '78-5-1.jpg', '78-6-0.jpg', '78-6-1.jpg', '78-7-1.jpg', '78-8-0.jpg', '78-8-1.jpg', '78-9-0.jpg', '78-9-1.jpg', '78-10-1.jpg', '78-10-0.jpg', '77-1-0.jpg', '79-1-0.jpg', '79-2-1.jpg', '79-2-0.jpg', '79-3-1.jpg', '79-3-0.jpg', '79-4-1.jpg', '79-4-0.jpg', '74-1-1.jpg', '74-1-0.jpg', '74-2-1.jpg', '74-2-0.jpg', '74-3-1.jpg', '74-3-0.jpg', '74-4-1.jpg', '74-4-0.jpg', '74-5-1.jpg', '74-5-0.jpg', '76-1-0.jpg', '83-1-0.jpg', '83-1-1.jpg', '83-2-0.jpg', '83-2-1.jpg', '83-3-1.jpg', '83-3-0.jpg', '82-1-1.jpg', '82-1-0.jpg', '82-2-1.jpg', '82-2-0.jpg', '82-3-1.jpg
# ...

# %% [markdown]
# #**フォルダをダウンロード**

# %%
from google.colab import files
files.download(dst_folder)
