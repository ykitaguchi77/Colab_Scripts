# %% [markdown]
# <a href="https://colab.research.google.com/github/ykitaguchi77/Colab_Scripts/blob/master/Tesseract.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !apt install tesseract-ocr libtesseract-dev tesseract-ocr-jpn
# !pip install pyocr
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# libtesseract-dev is already the newest version (4.00~git2288-10f4998a-2).
# tesseract-ocr is already the newest version (4.00~git2288-10f4998a-2).
# The following package was automatically installed and is no longer required:
#   libnvidia-common-460
# Use 'apt autoremove' to remove it.
# The following NEW packages will be installed:
#   tesseract-ocr-jpn
# 0 upgraded, 1 newly installed, 0 to remove and 42 not upgraded.
# Need to get 1,389 kB of archives.
# After this operation, 2,486 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu bionic/universe amd64 tesseract-ocr-jpn all 4.00~git24-0e00fe6-1.2 [1,389 kB]
# Fetched 1,389 kB in 0s (12.0 MB/s)
# Selecting previously unselected package tesseract-ocr-jpn.
# (Reading database ... 155787 files and directories currently installed.)
# Preparing to unpack .../tesseract-ocr-jpn_4.00~git24-0e00fe6-1.2_all.deb ...
# ...

# %%
#OCRを行う画像を読み込み
from google.colab import files
f = files.upload()
#読み込んだ画像のファイル名
filename = list(f)[0]
# Out:
#      <input type="file" id="files-c0c62c98-7562-4747-9cce-163b240b16ca" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-c0c62c98-7562-4747-9cce-163b240b16ca">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving スクリーンショット 2022-05-30 23.19.04.png to スクリーンショット 2022-05-30 23.19.04.png

# %%
import glob

files = glob.glob("/content/drive/MyDrive/副業/コンテンツビジネス/恋愛商材/フリーサンプル/マッチングアプリプロフィール/29-600-1/*")
print(files)
# Out:
# ['/content/drive/MyDrive/副業/コンテンツビジネス/恋愛商材/フリーサンプル/マッチングアプリプロフィール/29-600-1/IMG_7198.PNG', '/content/drive/MyDrive/副業/コンテンツビジネス/恋愛商材/フリーサンプル/マッチングアプリプロフィール/29-600-1/IMG_7200.PNG', '/content/drive/MyDrive/副業/コンテンツビジネス/恋愛商材/フリーサンプル/マッチングアプリプロフィール/29-600-1/IMG_7197.PNG', '/content/drive/MyDrive/副業/コンテンツビジネス/恋愛商材/フリーサンプル/マッチングアプリプロフィール/29-600-1/IMG_7199.PNG', '/content/drive/MyDrive/副業/コンテンツビジネス/恋愛商材/フリーサンプル/マッチングアプリプロフィール/29-600-1/IMG_7202.PNG', '/content/drive/MyDrive/副業/コンテンツビジネス/恋愛商材/フリーサンプル/マッチングアプリプロフィール/29-600-1/IMG_7201.PNG', '/content/drive/MyDrive/副業/コンテンツビジネス/恋愛商材/フリーサンプル/マッチングアプリプロフィール/29-600-1/IMG_7204.PNG', '/content/drive/MyDrive/副業/コンテンツビジネス/恋愛商材/フリーサンプル/マッチングアプリプロフィール/29-600-1/IMG_7203.PNG', '/content/drive/MyDrive/副業/コンテンツビジネス/恋愛商材/フリーサンプル/マッチングアプリプロフィール/29-600-1/IMG_7205.PNG']

# %%
 #読み込んだ画像をOCRでテキスト抽出してみる。
import sys
import pyocr
import pyocr.builders
import cv2
from PIL import Image
import matplotlib.pyplot as plt

tools = pyocr.get_available_tools()
tool = tools[0]


def read_text(path):
    im = cv2.imread(path)
    im_gray = cv2.cvtColor(im, cv2.COLOR_BGR2GRAY)
    im_blur = cv2.GaussianBlur(im_gray, (5, 5), 0)
    th1 = cv2.adaptiveThreshold(im_blur, 255, cv2.ADAPTIVE_THRESH_GAUSSIAN_C, cv2.THRESH_BINARY, 11, 2)
    txt = tool.image_to_string(
      Image.fromarray(im_gray),
      lang = 'eng+jpn'
    )
    return txt

for i in files:
    txt = read_text(i)
    print(txt)
# Out:
# 23:12 als a)
#
# x ta さん の 参加 コミ ュ ニ ティ
#
# 趣味 ライ フス タイ ル 価値 観
#
#
#
#
#
# — He IC HRT OF
# 画 を 立て た い !
#
#
#
#
#
#
#
#
#
#
#
# ジョ ジョ の 奇妙 恋人 (彼氏 ・ 彼 恋人 の 趣味 も 一
# な 冒険 女 ) が オタ ク .… 緒 に 楽し みた い
# 23:29 eal > a)
#
# xX ta さん の 参加 コミ ュ ニ ティ
#
# 趣味 ライ フス タイ ル 価値 観
#
#
#
#
#
#
# 2 Neee
# 美味 い お 酒 と 旨
# い 食 べ も の が .…
#
#
#
# 一 緒 に 呑み に い 良い も の を 大 切 食べ 方 が 綺麗 な
# ける お 酒好き .… に 使い た い 人 が 好き
#
#
#
#
#
#
#
#
#
# £
#
# 甘い も の 大 好き
#
#
#
#
# オシ ャ レ な カフ
# ェ 巡 り し た い
#
# AW.) ——3
# 23:12 als @)
#
#
#
#
#
# ta @
# 29 歳 東京 〈③ ワク チン 接種 済み
# 英語 と 剣道 を 教え て いま す
# 24 時 間 以 内 形相 性 59% 500+ いい ね !
# y
# コミ (
# あと 27 いい ね ! 無料 © 15:32
#
#
#
# Oy とら と キーーー
# 23:29 als a)
#
# x ta さん の 参加 コミ ュ ニ ティ
#
# 趣味 ライ フス タイ ル 価値 観
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 1) TAS
# レト ロ な 建築 て 歴史 的 建造 物 大 美術 館 ・ 博 物
# 洋館 ・ ビ ル が .… 好き 好き
#
#
#
#
#
#
#
#
#
#
#
# 漫画 が 好き アニ メ ・ 漫 画 ・
# ルト ゲー ム 大 好き .…
#
#
#
# 映画 が 好き
# 23:29 als a)
#
# x ta さん の 参加 コミ ュ ニ ティ
#
# 価値 観
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ...

# %%
cv2.imread("/content/drive/MyDrive/副業/コンテンツビジネス/恋愛商材/フリーサンプル/マッチングアプリプロフィール/29-600-1/IMG_7198.PNG")
# Out:
# array([[[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        ...,
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
# ...
