# %% [markdown]
# <a href="https://colab.research.google.com/github/ykitaguchi77/Colab_Scripts/blob/master/Convert%20PNG%20to%20JPEG.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**PNGをJPGに変換するスクリプト**

# %%
#google driveをcolabolatoryにマウント
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
input_path = "/content/drive/MyDrive/Deep_learning/FundusPhoto/vascular_img"
out_path = "/content/drive/MyDrive/Deep_learning/FundusPhoto/vascular_img"
flag_delete_original_files = True # 元ファイルを削除する場合は、True指定

# %%
import glob
import os
from PIL import Image

filepath_list = glob.glob(input_path + '/*.png') # .pngファイルをリストで取得する
for filepath in filepath_list:
    basename  = os.path.basename(filepath) # ファイルパスからファイル名を取得
    save_filepath = out_path + '/' + basename [:-4] + '.jpg' # 保存ファイルパスを作成
    img = Image.open(filepath)
    img = img.convert('RGB') # RGBA(png)→RGB(jpg)へ変換
    img.save(save_filepath, "JPEG", quality=95)
    print(filepath, '->', save_filepath)
    if flag_delete_original_files:
        os.remove(filepath)
        print('delete', filepath)
# Out:
# /content/drive/MyDrive/Deep_learning/FundusPhoto/vascular_img/img24590673_10_2L.png -> /content/drive/MyDrive/Deep_learning/FundusPhoto/vascular_img/img24590673_10_2L.jpg
# delete /content/drive/MyDrive/Deep_learning/FundusPhoto/vascular_img/img24590673_10_2L.png
# /content/drive/MyDrive/Deep_learning/FundusPhoto/vascular_img/img24590673_11_1R.png -> /content/drive/MyDrive/Deep_learning/FundusPhoto/vascular_img/img24590673_11_1R.jpg
# delete /content/drive/MyDrive/Deep_learning/FundusPhoto/vascular_img/img24590673_11_1R.png
# /content/drive/MyDrive/Deep_learning/FundusPhoto/vascular_img/img24738913_01_1R.png -> /content/drive/MyDrive/Deep_learning/FundusPhoto/vascular_img/img24738913_01_1R.jpg
# delete /content/drive/MyDrive/Deep_learning/FundusPhoto/vascular_img/img24738913_01_1R.png
# /content/drive/MyDrive/Deep_learning/FundusPhoto/vascular_img/img24738913_02_1R.png -> /content/drive/MyDrive/Deep_learning/FundusPhoto/vascular_img/img24738913_02_1R.jpg
# ...
