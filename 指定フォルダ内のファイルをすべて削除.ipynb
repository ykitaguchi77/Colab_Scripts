# %% [markdown]
# <a href="https://colab.research.google.com/github/ykitaguchi77/Colab_Scripts/blob/master/%E6%8C%87%E5%AE%9A%E3%83%95%E3%82%A9%E3%83%AB%E3%83%80%E5%86%85%E3%81%AE%E3%83%95%E3%82%A1%E3%82%A4%E3%83%AB%E3%82%92%E3%81%99%E3%81%B9%E3%81%A6%E5%89%8A%E9%99%A4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #指定フォルダ内のファイルをすべて削除するスクリプト

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive
# Tue, 28 Apr 2020 10:43:23 +0000
# Tue, 28 Apr 2020 10:43:29 +0000
# drive  sample_data  train  val

# %% [markdown]
# #フォルダ内のファイルのみ削除したいとき（ファイル形式でないものは残る）

# %%
import os

directory = 'ここにパスをコピペ'
files = os.listdir(directory)
print(directory)
print(files)

for i in files:
    try:
        os.remove(directory+'/'+i)
    except IsADirectoryError:
        pass

# %% [markdown]
# #フォルダごと削除したいとき

# %%
import shutil

directory = 'ここにパスをコピペ'

try:
    shutil.rmtree(directory)
except FileNotFoundError:
    pass

# %% [markdown]
# #フォルダそのものは残して中身だけ削除したいとき

# %%
import shutil

directory = 'ここにパスをコピペ'

try:
    shutil.rmtree(directory)
except FileNotFoundError:
    pass

#同名のフォルダを作成する
os.mkdir(directory)
