# %% [markdown]
# <a href="https://colab.research.google.com/github/ykitaguchi77/Colab_Scripts/blob/master/CSV%E3%81%A7%E4%B8%80%E8%87%B4%E3%81%99%E3%82%8B%E3%82%AB%E3%83%A9%E3%83%A0%E3%82%92%E5%8F%82%E7%85%A7%E3%81%97%E3%81%A6%E3%82%B3%E3%83%94%E3%83%BC.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#google driveをcolabolatoryにマウント
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd

def openCSV(csv_path):
    df = pd.read_csv(csv_path)
    df = df.drop(df.columns[[0]], axis=1) #1列目を削除する
    print(df)
    return df

#CSVを開く （csv1:編集するファイル、csv2:参照するファイル）
csv1_path = '/content/drive/My Drive/Grav_bootcamp/Posttrain_eval_2.csv'
csv2_path = '/content/drive/My Drive/Hum_eval.csv'

df1, df2 = openCSV(csv1_path), openCSV(csv2_path) #CSVを開く
# Out:
#      image_name Label  Nakagawa  kitaguchi  inoue  kohzaki  EfficientNet
# 0            57  grav       NaN        NaN    NaN      NaN           NaN
# 1            66  cont       NaN        NaN    NaN      NaN           NaN
# 2           118  cont       NaN        NaN    NaN      NaN           NaN
# 3           122  grav       NaN        NaN    NaN      NaN           NaN
# 4           132  cont       NaN        NaN    NaN      NaN           NaN
# 5           149  cont       NaN        NaN    NaN      NaN           NaN
# 6           229  cont       NaN        NaN    NaN      NaN           NaN
# 7           259  cont       NaN        NaN    NaN      NaN           NaN
# 8           385  grav       NaN        NaN    NaN      NaN           NaN
# 9           513  cont       NaN        NaN    NaN      NaN           NaN
# 10          555  grav       NaN        NaN    NaN      NaN           NaN
# 11          782  grav       NaN        NaN    NaN      NaN           NaN
# 12          806  cont       NaN        NaN    NaN      NaN           NaN
# 13          818  grav       NaN        NaN    NaN      NaN           NaN
# 14          861  cont       NaN        NaN    NaN      NaN           NaN
# 15          969  cont       NaN        NaN    NaN      NaN           NaN
# 16         1079  cont       NaN        NaN    NaN      NaN           NaN
# 17         1094  cont       NaN        NaN    NaN      NaN           NaN
# 18         1284  grav       NaN        NaN    NaN      NaN           NaN
# 19         1336  grav       NaN        NaN    NaN      NaN           NaN
# 20         1378  grav       NaN        NaN    NaN      NaN           NaN
# 21         1381  cont       NaN        NaN    NaN      NaN           NaN
# 22         1413  cont       NaN        NaN    NaN      NaN           NaN
# 23         1457  grav       NaN        NaN    NaN      NaN           NaN
# 24         1525  grav       NaN        NaN    NaN      NaN           NaN
# 25         1768  cont       NaN        NaN    NaN      NaN           NaN
# 26         1773  grav       NaN        NaN    NaN      NaN           NaN
# 27         1786  grav       NaN        NaN    NaN      NaN           NaN
# 28         1805  cont       NaN        NaN    NaN      NaN           NaN
# 29         1841  grav       NaN        NaN    NaN      NaN           NaN
# 30         1976  grav       NaN        NaN    NaN      NaN           NaN
# 31         1994  cont       NaN        NaN    NaN      NaN           NaN
# 32         2164  cont       NaN        NaN    NaN      NaN           NaN
# 33         2169  cont       NaN        NaN    NaN      NaN           NaN
# 34         2366  cont       NaN        NaN    NaN      NaN           NaN
# 35         2371  cont       NaN        NaN    NaN      NaN           NaN
# 36         2377  cont       NaN        NaN    NaN      NaN           NaN
# 37         2384  cont       NaN        NaN    NaN      NaN           NaN
# 38         2607  cont       NaN        NaN    NaN      NaN           NaN
# 39         2684  grav       NaN        NaN    NaN      NaN           NaN
# 40         2726  grav       NaN        NaN    NaN      NaN           NaN
# 41         2762  grav       NaN        NaN    NaN      NaN           NaN
# 42         2853  grav       NaN        NaN    NaN      NaN           NaN
# 43         2969  cont       NaN        NaN    NaN      NaN           NaN
# 44         3039  cont       NaN        NaN    NaN      NaN           NaN
# 45         3144  grav       NaN        NaN    NaN      NaN           NaN
# 46         3193  cont       NaN        NaN    NaN      NaN           NaN
# 47         3209  grav       NaN        NaN    NaN      NaN           NaN
# 48         3331  grav       NaN        NaN    NaN      NaN           NaN
# 49         3511  grav       NaN        NaN    NaN      NaN           NaN
# 50         3543  grav       NaN        NaN    NaN      NaN           NaN
# 51         3588  cont       NaN        NaN    NaN      NaN           NaN
# 52         3663  cont       NaN        NaN    NaN      NaN           NaN
# 53         3695  grav       NaN        NaN    NaN      NaN           NaN
# 54         4135  cont       NaN        NaN    NaN      NaN           NaN
# 55         4292  grav       NaN        NaN    NaN      NaN           NaN
# 56         4355  cont       NaN        NaN    NaN      NaN           NaN
# 57         4372  cont       NaN        NaN    NaN      NaN           NaN
# 58         4386  cont       NaN        NaN    NaN      NaN           NaN
# 59         4456  cont       NaN        NaN    NaN      NaN           NaN
# 60         4486  grav       NaN        NaN    NaN      NaN           NaN
# 61         4540  grav       NaN        NaN    NaN      NaN           NaN
# 62         4813  grav       NaN        NaN    NaN      NaN           NaN
# 63         4817  cont       NaN        NaN    NaN      NaN           NaN
# 64         4835  cont       NaN        NaN    NaN      NaN           NaN
# 65         4947  cont       NaN        NaN    NaN      NaN           NaN
# 66         4997  grav       NaN        NaN    NaN      NaN           NaN
# 67         5015  grav       NaN        NaN    NaN      NaN           NaN
# 68         5069  grav       NaN        NaN    NaN      NaN           NaN
# 69         5214  cont       NaN        NaN    NaN      NaN           NaN
# 70         5281  cont       NaN        NaN    NaN      NaN           NaN
# 71         5299  grav       NaN        NaN    NaN      NaN           NaN
# 72         5302  cont       NaN        NaN    NaN      NaN           NaN
# 73         5335  grav       NaN        NaN    NaN      NaN           NaN
# 74         5378  grav       NaN        NaN    NaN      NaN           NaN
# 75         5466  cont       NaN        NaN    NaN      NaN           NaN
# 76         5481  cont       NaN        NaN    NaN      NaN           NaN
# 77         5551  grav       NaN        NaN    NaN      NaN           NaN
# 78         5586  grav       NaN        NaN    NaN      NaN           NaN
# 79         5599  cont       NaN        NaN    NaN      NaN           NaN
# 80         5608  grav       NaN        NaN    NaN      NaN           NaN
# 81         5646  grav       NaN        NaN    NaN      NaN           NaN
# 82         5714  cont       NaN        NaN    NaN      NaN           NaN
# 83         5749  cont       NaN        NaN    NaN      NaN           NaN
# 84         5758  grav       NaN        NaN    NaN      NaN           NaN
# 85         5763  grav       NaN        NaN    NaN      NaN           NaN
# 86         5838  grav       NaN        NaN    NaN      NaN           NaN
# 87         5989  grav       NaN        NaN    NaN      NaN           NaN
# 88         6003  grav       NaN        NaN    NaN      NaN           NaN
# 89         6060  cont       NaN        NaN    NaN      NaN           NaN
# 90         6297  grav       NaN        NaN    NaN      NaN           NaN
# 91         6361  cont       NaN        NaN    NaN      NaN           NaN
# 92         6502  grav       NaN        NaN    NaN      NaN           NaN
# 93         6513  grav       NaN        NaN    NaN      NaN           NaN
# 94         6706  cont       NaN        NaN    NaN      NaN           NaN
# 95         6855  grav       NaN        NaN    NaN      NaN           NaN
# 96         6888  cont       NaN        NaN    NaN      NaN           NaN
# 97         6913  cont       NaN        NaN    NaN      NaN           NaN
# 98         7044  grav       NaN        NaN    NaN      NaN           NaN
# 99         7193  cont       NaN        NaN    NaN      NaN           NaN
# 100        7302  grav       NaN        NaN    NaN      NaN           NaN
# 101        7428  grav       NaN        NaN    NaN      NaN           NaN
# 102        7466  cont       NaN        NaN    NaN      NaN           NaN
# 103        7726  cont       NaN        NaN    NaN      NaN           NaN
# 104        7745  grav       NaN        NaN    NaN      NaN           NaN
# 105        7763  grav       NaN        NaN    NaN      NaN           NaN
# 106        8079  grav       NaN        NaN    NaN      NaN           NaN
# 107        8120  cont       NaN        NaN    NaN      NaN           NaN
#      image_name Label Inoue kohzaki  morimoto kitaguchi  kawasaki
# 0            17  grav  grav    grav       NaN      grav       NaN
# 1            19  grav  cont    cont       NaN      grav       NaN
# 2            57  grav  grav    grav       NaN      grav       NaN
# 3            66  cont  cont    cont       NaN      cont       NaN
# 4            85  cont  cont    cont       NaN      cont       NaN
# 5           118  cont  cont    cont       NaN      cont       NaN
# 6           122  grav  grav    cont       NaN      grav       NaN
# 7           129  grav  cont    grav       NaN      grav       NaN
# 8           132  cont  cont    grav       NaN      grav       NaN
# 9           144  cont  cont    cont       NaN      cont       NaN
# 10          147  cont  cont    grav       NaN      grav       NaN
# 11          149  cont  cont    cont       NaN      cont       NaN
# 12          155  grav  grav    grav       NaN      grav       NaN
# 13          168  cont  cont    cont       NaN      cont       NaN
# 14          172  cont  cont    cont       NaN      cont       NaN
# 15          180  grav  grav    grav       NaN      grav       NaN
# 16          186  cont  cont    cont       NaN      cont       NaN
# 17          191  cont  cont    cont       NaN      cont       NaN
# 18          200  cont  cont    cont       NaN      cont       NaN
# 19          214  cont  cont    grav       NaN      cont       NaN
# 20          229  cont  cont    cont       NaN      cont       NaN
# 21          255  cont  cont    cont       NaN      cont       NaN
# 22          259  cont  cont    cont       NaN      cont       NaN
# 23          278  cont  cont    cont       NaN      cont       NaN
# 24          364  cont  cont    cont       NaN      cont       NaN
# 25          374  grav  grav    grav       NaN      grav       NaN
# 26          383  cont  cont    grav       NaN      grav       NaN
# 27          385  grav  cont    grav       NaN      grav       NaN
# 28          398  cont  cont    cont       NaN      cont       NaN
# 29          401  cont  cont    cont       NaN      cont       NaN
# 30          425  grav  grav    grav       NaN      grav       NaN
# 31          426  grav  grav    grav       NaN      grav       NaN
# 32          429  grav  cont    cont       NaN      cont       NaN
# 33          444  cont  cont    cont       NaN      cont       NaN
# 34          465  grav  cont    grav       NaN      cont       NaN
# 35          466  grav  grav    grav       NaN      grav       NaN
# 36          469  cont  cont    cont       NaN      cont       NaN
# 37          489  grav  cont    cont       NaN      grav       NaN
# 38          490  cont  cont    cont       NaN      cont       NaN
# 39          507  grav  grav    grav       NaN      grav       NaN
# 40          513  cont  cont    cont       NaN      cont       NaN
# 41          514  cont  cont    cont       NaN      cont       NaN
# 42          533  grav  grav    grav       NaN      grav       NaN
# 43          534  grav  grav    grav       NaN      grav       NaN
# 44          542  cont  cont    cont       NaN      cont       NaN
# 45          555  grav  grav    grav       NaN      grav       NaN
# 46          562  cont  cont    cont       NaN      cont       NaN
# 47          611  grav  grav    grav       NaN      grav       NaN
# 48          641  cont  cont    cont       NaN      cont       NaN
# 49          646  cont  cont    cont       NaN      cont       NaN
# 50          718  grav  grav    grav       NaN      grav       NaN
# 51          724  grav  grav    grav       NaN      grav       NaN
# 52          742  cont  cont    grav       NaN      cont       NaN
# 53          745  cont  cont    cont       NaN      cont       NaN
# 54          760  cont  cont    cont       NaN      cont       NaN
# 55          782  grav  grav    grav       NaN      grav       NaN
# 56          787  grav  grav    grav       NaN      grav       NaN
# 57          802  cont  cont    cont       NaN      cont       NaN
# 58          806  cont  cont    cont       NaN      cont       NaN
# 59          811  cont  cont    cont       NaN      cont       NaN
# 60          818  grav  grav    grav       NaN      grav       NaN
# 61          861  cont  cont    cont       NaN      cont       NaN
# 62          863  cont  cont    cont       NaN      cont       NaN
# 63          876  grav  grav    grav       NaN      grav       NaN
# 64          893  grav  grav    grav       NaN      grav       NaN
# 65          896  cont  cont    grav       NaN      cont       NaN
# 66          948  cont  cont    cont       NaN      cont       NaN
# 67          950  grav  grav    grav       NaN      grav       NaN
# 68          957  grav  grav    grav       NaN      grav       NaN
# 69          958  cont  cont    cont       NaN      cont       NaN
# 70          965  grav  grav    grav       NaN      grav       NaN
# 71          969  cont  cont    cont       NaN      cont       NaN
# 72          977  grav  grav    grav       NaN      grav       NaN
# 73          983  grav  grav    grav       NaN      grav       NaN
# 74         1000  cont  cont    cont       NaN      cont       NaN
# 75         1001  grav  cont    cont       NaN      grav       NaN
# 76         1020  grav  cont    grav       NaN      grav       NaN
# 77         1037  grav  grav    grav       NaN      cont       NaN
# 78         1043  cont  cont    cont       NaN      grav       NaN
# 79         1045  cont  cont    cont       NaN      cont       NaN
# 80         1050  cont  cont    cont       NaN      cont       NaN
# 81         1054  cont  cont    cont       NaN      cont       NaN
# 82         1079  cont  cont    cont       NaN      cont       NaN
# 83         1084  cont  cont    cont       NaN      cont       NaN
# 84         1086  cont  cont    cont       NaN      cont       NaN
# 85         1088  grav  grav    grav       NaN      grav       NaN
# 86         1094  cont  cont    cont       NaN      cont       NaN
# 87         1126  cont  cont    cont       NaN      cont       NaN
# 88         1143  cont  cont    cont       NaN      cont       NaN
# 89         1144  cont  cont    cont       NaN      cont       NaN
# 90         1160  cont  cont    cont       NaN      cont       NaN
# 91         1182  cont  cont    cont       NaN      cont       NaN
# 92         1231  grav  grav    grav       NaN      grav       NaN
# 93         1249  cont  cont    cont       NaN      cont       NaN
# 94         1263  cont  cont    cont       NaN      cont       NaN
# 95         1266  cont  cont    cont       NaN      cont       NaN
# 96         1270  grav  grav    grav       NaN      grav       NaN
# 97         1284  grav  grav    grav       NaN      grav       NaN
# 98         1304  grav  cont    cont       NaN      cont       NaN
# 99         1313  grav  grav    grav       NaN      grav       NaN
# 100        1320  cont  cont    cont       NaN      cont       NaN
# 101        1322  cont  cont    grav       NaN      grav       NaN
# 102        1333  grav  grav    grav       NaN      grav       NaN
# 103        1336  grav  grav    grav       NaN      grav       NaN
# 104        1338  cont  cont    cont       NaN      cont       NaN
# 105        1342  cont  cont    cont       NaN      cont       NaN
# 106        1347  grav  cont    cont       NaN      grav       NaN
# 107        1348  cont  cont    grav       NaN      grav       NaN
# 108        1357  grav  grav    grav       NaN      cont       NaN
# 109        1360  cont  cont    cont       NaN      cont       NaN
# 110        1361  cont  cont    cont       NaN      cont       NaN
# 111        1369  cont  cont    cont       NaN      cont       NaN
# 112        1370  grav  grav    cont       NaN      grav       NaN
# 113        1378  grav  cont    cont       NaN      cont       NaN
# 114        1381  cont  cont    cont       NaN      cont       NaN
# 115        1385  grav  grav    grav       NaN      grav       NaN
# 116        1396  grav  cont    cont       NaN      grav       NaN
# 117        1413  cont  cont    cont       NaN      cont       NaN
# 118        1423  cont  cont    cont       NaN      grav       NaN
# 119        1428  cont  cont    cont       NaN      cont       NaN
# 120        1429  grav  grav    grav       NaN      grav       NaN
# 121        1432  grav  cont    cont       NaN      grav       NaN
# 122        1438  grav  grav    grav       NaN      grav       NaN
# 123        1446  grav  grav    grav       NaN      grav       NaN
# 124        1451  cont  cont    cont       NaN      cont       NaN
# 125        1453  grav  grav    grav       NaN      grav       NaN
# 126        1457  grav  grav    cont       NaN      grav       NaN
# 127        1468  cont  cont    cont       NaN      cont       NaN
# 128        1488  cont  cont    cont       NaN      cont       NaN
# 129        1498  cont  cont    cont       NaN      cont       NaN
# 130        1501  grav  cont    cont       NaN      cont       NaN
# 131        1503  grav  cont    cont       NaN      cont       NaN
# 132        1524  grav  grav    grav       NaN      grav       NaN
# 133        1525  grav  cont    grav       NaN      cont       NaN
# 134        1528  grav  grav    grav       NaN      grav       NaN
# 135        1553  grav  cont    grav       NaN      grav       NaN
# 136        1597  grav  cont    grav       NaN      grav       NaN
# 137        1601  cont  cont    cont       NaN      cont       NaN
# 138        1605  cont  cont    cont       NaN      cont       NaN
# 139        1619  cont  cont    cont       NaN      cont       NaN
# 140        1638  cont  grav    cont       NaN      cont       NaN
# 141        1664  grav  cont    cont       NaN      grav       NaN
# 142        1682  grav  grav    grav       NaN      grav       NaN
# 143        1729  grav  cont    grav       NaN      cont       NaN
# 144        1743  grav  grav    grav       NaN      grav       NaN
# 145        1759  cont  cont    cont       NaN      cont       NaN
# 146        1762  cont  cont    cont       NaN      grav       NaN
# 147        1764  grav  grav    grav       NaN      grav       NaN
# 148        1768  cont  cont    cont       NaN      cont       NaN
# 149        1773  grav  cont    grav       NaN      grav       NaN
# 150        1786  grav  grav    grav       NaN      grav       NaN
# 151        1794  cont  cont    cont       NaN      cont       NaN
# 152        1805  cont  cont    cont       NaN      cont       NaN
# 153        1813  cont  cont    cont       NaN      cont       NaN
# 154        1815  grav  grav    grav       NaN      grav       NaN
# 155        1821  cont  cont    cont       NaN      cont       NaN
# 156        1823  cont  cont    cont       NaN      cont       NaN
# 157        1841  grav  grav    grav       NaN      cont       NaN
# 158        1900  cont  cont    cont       NaN      cont       NaN
# 159        1910  grav  grav    grav       NaN      grav       NaN
# 160        1913  grav  cont    grav       NaN      cont       NaN
# 161        1918  cont  cont    cont       NaN      cont       NaN
# 162        1931  grav  grav    grav       NaN      grav       NaN
# 163        1954  cont  cont    cont       NaN      cont       NaN
# 164        1976  grav  cont    grav       NaN      grav       NaN
# 165        1994  cont  cont    cont       NaN      cont       NaN
# 166        1995  grav  cont    cont       NaN      grav       NaN
# 167        2007  grav  cont    grav       NaN      grav       NaN
# 168        2034  cont  cont    cont       NaN      grav       NaN
# 169        2042  grav  grav    grav       NaN      grav       NaN
# 170        2054  cont  cont    cont       NaN      cont       NaN
# 171        2076  cont  cont    cont       NaN      cont       NaN
# 172        2083  cont  cont    cont       NaN      cont       NaN
# 173        2110  cont  cont    cont       NaN      cont       NaN
# 174        2118  cont  cont    cont       NaN      cont       NaN
# 175        2139  cont  cont    cont       NaN      cont       NaN
# 176        2148  grav  cont    cont       NaN      cont       NaN
# 177        2164  cont  cont    cont       NaN      cont       NaN
# 178        2168  cont  cont    cont       NaN      cont       NaN
# 179        2169  cont  cont    grav       NaN      grav       NaN
# 180        2174  cont  cont    cont       NaN      cont       NaN
# 181        2180  cont  cont    cont       NaN      cont       NaN
# 182        2182  grav  grav    grav       NaN      grav       NaN
# 183        2189  grav  grav    grav       NaN      grav       NaN
# 184        2203  grav  grav    grav       NaN      grav       NaN
# 185        2206  cont  cont    cont       NaN      cont       NaN
# 186        2214  cont  cont    cont       NaN      cont       NaN
# 187        2222  grav  grav    grav       NaN      grav       NaN
# 188        2231  grav  cont    cont       NaN      cont       NaN
# 189        2236  cont  cont    grav       NaN      cont       NaN
# 190        2274  grav  cont    grav       NaN      cont       NaN
# 191        2290  cont  cont    cont       NaN      cont       NaN
# 192        2307  grav  cont    grav       NaN      grav       NaN
# 193        2308  cont  cont    cont       NaN      grav       NaN
# 194        2321  grav  cont    cont       NaN      grav       NaN
# 195        2332  cont  cont    cont       NaN      cont       NaN
# 196        2338  cont  cont    cont       NaN      cont       NaN
# 197        2351  cont  grav    grav       NaN      cont       NaN
# 198        2366  cont  cont    cont       NaN      cont       NaN
# 199        2370  grav  grav    grav       NaN      grav       NaN
# 200        2371  cont  cont    cont       NaN      cont       NaN
# 201        2377  cont  cont    cont       NaN      cont       NaN
# 202        2384  cont  cont    cont       NaN      cont       NaN
# 203        2407  grav  grav    grav       NaN      grav       NaN
# 204        2413  cont  cont    cont       NaN      cont       NaN
# 205        2414  grav  grav    grav       NaN      grav       NaN
# 206        2436  grav  grav    grav       NaN      grav       NaN
# 207        2446  cont  cont    cont       NaN      cont       NaN
# 208        2450  cont  cont    grav       NaN      grav       NaN
# 209        2508  grav  grav    grav       NaN      grav       NaN
# 210        2510  grav  grav    grav       NaN      grav       NaN
# 211        2515  cont  cont    cont       NaN      cont       NaN
# 212        2546  cont  cont    cont       NaN      cont       NaN
# 213        2549  cont  cont    cont       NaN      cont       NaN
# 214        2550  cont  cont    cont       NaN      cont       NaN
# 215        2556  cont  grav    grav       NaN      grav       NaN
# 216        2558  grav  cont    grav       NaN      grav       NaN
# 217        2565  cont  cont    cont       NaN      cont       NaN
# 218        2597  cont  cont    cont       NaN      cont       NaN
# 219        2607  cont  cont    cont       NaN      cont       NaN
# 220        2623  grav  cont    grav       NaN      grav       NaN
# 221        2630  grav  cont    cont       NaN      grav       NaN
# 222        2644  grav  grav    grav       NaN      grav       NaN
# 223        2664  grav  cont    cont       NaN      grav       NaN
# 224        2668  grav  grav    cont       NaN      grav       NaN
# 225        2670  grav  cont    cont       NaN      grav       NaN
# 226        2684  grav  cont    grav       NaN      grav       NaN
# 227        2689  grav  grav    grav       NaN      grav       NaN
# 228        2709  grav  cont    grav       NaN      grav       NaN
# 229        2726  grav  cont    grav       NaN      grav       NaN
# 230        2741  cont  cont    cont       NaN      cont       NaN
# 231        2762  grav  grav    grav       NaN      grav       NaN
# 232        2771  cont  cont    cont       NaN      cont       NaN
# 233        2794  grav  cont    grav       NaN      grav       NaN
# 234        2801  grav  grav    grav       NaN      grav       NaN
# 235        2803  grav  grav    grav       NaN      grav       NaN
# 236        2825  cont  cont    cont       NaN      cont       NaN
# 237        2837  grav  grav    grav       NaN      grav       NaN
# 238        2847  cont  cont    grav       NaN      cont       NaN
# 239        2851  grav  grav    grav       NaN      grav       NaN
# 240        2853  grav  cont    grav       NaN      grav       NaN
# 241        2866  cont  cont    grav       NaN      cont       NaN
# 242        2880  cont  grav    cont       NaN      grav       NaN
# 243        2885  grav  cont    cont       NaN      grav       NaN
# 244        2900  grav  cont    cont       NaN      grav       NaN
# 245        2960  grav  cont    grav       NaN      grav       NaN
# 246        2967  grav  cont    cont       NaN      grav       NaN
# 247        2968  cont  cont    cont       NaN      grav       NaN
# 248        2969  cont  cont    cont       NaN      cont       NaN
# 249        2974  grav  grav    grav       NaN      grav       NaN
# 250        2979  cont  cont    cont       NaN      cont       NaN
# 251        3003  cont  cont    cont       NaN      cont       NaN
# 252        3039  cont  cont    grav       NaN      cont       NaN
# 253        3046  grav  grav    grav       NaN      grav       NaN
# 254        3056  grav  grav    grav       NaN      cont       NaN
# 255        3077  grav  cont    grav       NaN      cont       NaN
# 256        3098  cont  cont    cont       NaN      cont       NaN
# 257        3102  cont  cont    cont       NaN      cont       NaN
# 258        3128  grav  cont    cont       NaN      grav       NaN
# 259        3144  grav  grav    grav       NaN      grav       NaN
# 260        3162  grav  grav    grav       NaN      grav       NaN
# 261        3164  grav  cont    cont       NaN      grav       NaN
# 262        3167  grav  cont    cont       NaN      grav       NaN
# 263        3176  grav  cont    cont       NaN      grav       NaN
# 264        3191  cont  cont    cont       NaN      cont       NaN
# 265        3193  cont  cont    cont       NaN      cont       NaN
# 266        3209  grav  grav    grav       NaN      grav       NaN
# 267        3217  grav  grav    grav       NaN      grav       NaN
# 268        3222  cont  cont    cont       NaN      cont       NaN
# 269        3237  grav  cont    grav       NaN      grav       NaN
# 270        3247  cont  cont    cont       NaN      cont       NaN
# 271        3264  grav  grav    grav       NaN      grav       NaN
# 272        3276  grav  grav    grav       NaN      grav       NaN
# 273        3331  grav  grav    grav       NaN      grav       NaN
# 274        3333  cont  cont    cont       NaN      cont       NaN
# 275        3352  grav  cont    cont       NaN      grav       NaN
# 276        3368  cont  cont    cont       NaN      cont       NaN
# 277        3381  cont  cont    cont       NaN      cont       NaN
# 278        3412  grav  grav    grav       NaN      grav       NaN
# 279        3428  grav  cont    cont       NaN      grav       NaN
# 280        3436  cont  cont    cont       NaN      cont       NaN
# 281        3444  grav  grav    grav       NaN      grav       NaN
# 282        3459  cont  cont    cont       NaN      cont       NaN
# 283        3472  grav  cont    grav       NaN      cont       NaN
# 284        3484  grav  cont    grav       NaN      grav       NaN
# 285        3496  grav  cont    cont       NaN      grav       NaN
# 286        3502  grav  cont    cont       NaN      grav       NaN
# 287        3511  grav  cont    grav       NaN      grav       NaN
# 288        3528  grav  cont    cont       NaN      grav       NaN
# 289        3532  grav  grav    grav       NaN      grav       NaN
# 290        3537  cont  cont    cont       NaN      cont       NaN
# 291        3543  grav  grav    grav       NaN      grav       NaN
# 292        3567  grav  cont    grav       NaN      grav       NaN
# 293        3568  grav  cont    grav       NaN      grav       NaN
# 294        3570  cont  cont    cont       NaN      cont       NaN
# 295        3578  cont  cont    cont       NaN      cont       NaN
# 296        3588  cont  cont    cont       NaN      cont       NaN
# 297        3600  grav  grav    grav       NaN      grav       NaN
# 298        3609  grav  grav    grav       NaN      grav       NaN
# 299        3646  grav  cont    cont       NaN      grav       NaN
# 300        3656  cont  cont    cont       NaN      cont       NaN
# 301        3663  cont  cont    cont       NaN      cont       NaN
# 302        3667  grav  cont    grav       NaN      grav       NaN
# 303        3668  cont  cont    cont       NaN      cont       NaN
# 304        3684  grav  cont    grav       NaN      cont       NaN
# 305        3695  grav  grav    grav       NaN      grav       NaN
# 306        3714  grav  grav    grav       NaN      grav       NaN
# 307        3728  cont  cont    cont       NaN      cont       NaN
# 308        3748  grav  grav    cont       NaN      grav       NaN
# 309        3752  grav  grav    grav       NaN      grav       NaN
# 310        3759  grav  grav    cont       NaN      cont       NaN
# 311        3771  cont  cont    cont       NaN      cont       NaN
# 312        3783  grav  cont    grav       NaN      grav       NaN
# 313        3784  cont  cont    cont       NaN      cont       NaN
# 314        3802  grav  cont    grav       NaN      grav       NaN
# 315        3809  grav  grav    grav       NaN      grav       NaN
# 316        3813  cont  cont    grav       NaN      grav       NaN
# 317        3843  grav  grav    grav       NaN      grav       NaN
# 318        3851  cont  cont    cont       NaN      cont       NaN
# 319        3857  cont  cont    cont       NaN      cont       NaN
# 320        3875  grav  grav    cont       NaN      grav       NaN
# 321        3878  cont  cont    cont       NaN      cont       NaN
# 322        3902  cont  cont    cont       NaN      cont       NaN
# 323        3906  cont  cont    cont       NaN      cont       NaN
# 324        3918  grav  grav    grav       NaN      grav       NaN
# 325        3929  grav  grav    grav       NaN      grav       NaN
# 326        3942  grav  grav    grav       NaN      grav       NaN
# 327        3976  grav  grav    grav       NaN      grav       NaN
# 328        3980  cont  cont    cont       NaN      cont       NaN
# 329        4008  grav  cont    grav       NaN      grav       NaN
# 330        4030  grav  grav    grav       NaN      grav       NaN
# 331        4042  cont  grav    grav       NaN      grav       NaN
# 332        4069  grav  cont    grav       NaN      grav       NaN
# 333        4111  cont  cont    cont       NaN      cont       NaN
# 334        4125  grav  cont    cont       NaN      cont       NaN
# 335        4135  cont  cont    cont       NaN      cont       NaN
# 336        4178  cont  cont    cont       NaN      cont       NaN
# 337        4194  cont  cont    cont       NaN      cont       NaN
# 338        4204  cont  cont    cont       NaN      cont       NaN
# 339        4206  grav  grav    grav       NaN      grav       NaN
# 340        4209  grav  grav    grav       NaN      grav       NaN
# 341        4222  cont  cont    cont       NaN      cont       NaN
# 342        4233  grav  grav    grav       NaN      grav       NaN
# 343        4250  cont  cont    cont       NaN      cont       NaN
# 344        4255  cont  cont    cont       NaN      cont       NaN
# 345        4263  grav  cont    grav       NaN      grav       NaN
# 346        4272  grav  grav    grav       NaN      grav       NaN
# 347        4273  cont  cont    cont       NaN      cont       NaN
# 348        4280  cont  cont    cont       NaN      cont       NaN
# 349        4292  grav  grav    grav       NaN      grav       NaN
# 350        4299  cont  cont    cont       NaN      cont       NaN
# 351        4329  cont  cont    cont       NaN      cont       NaN
# 352        4331  grav  grav    grav       NaN      grav       NaN
# 353        4332  grav  cont    grav       NaN      grav       NaN
# 354        4344  grav  grav    grav       NaN      grav       NaN
# 355        4355  cont  cont    cont       NaN      cont       NaN
# 356        4359  grav  grav    grav       NaN      grav       NaN
# 357        4372  cont  cont    cont       NaN      grav       NaN
# 358        4382  grav  grav    grav       NaN      grav       NaN
# 359        4386  cont  cont    cont       NaN      cont       NaN
# 360        4411  cont  cont    cont       NaN      cont       NaN
# 361        4438  cont  cont    cont       NaN      cont       NaN
# 362        4441  cont  cont    cont       NaN      cont       NaN
# 363        4447  cont  cont    cont       NaN      cont       NaN
# 364        4456  cont  cont    cont       NaN      cont       NaN
# 365        4457  cont  cont    cont       NaN      cont       NaN
# 366        4465  grav  grav    grav       NaN      grav       NaN
# 367        4480  grav  cont    cont       NaN      grav       NaN
# 368        4485  grav  grav    grav       NaN      grav       NaN
# 369        4486  grav  cont    grav       NaN      cont       NaN
# 370        4488  cont  cont    cont       NaN      cont       NaN
# 371        4525  cont  cont    cont       NaN      cont       NaN
# 372        4528  cont  cont    cont       NaN      cont       NaN
# 373        4540  grav  grav    grav       NaN      grav       NaN
# 374        4553  grav  grav    grav       NaN      grav       NaN
# 375        4560  cont  cont    cont       NaN      cont       NaN
# 376        4575  cont  cont    cont       NaN      cont       NaN
# 377        4577  grav  grav    grav       NaN      grav       NaN
# 378        4588  grav  cont    cont       NaN      cont       NaN
# 379        4606  grav  cont    cont       NaN      cont       NaN
# 380        4616  grav  grav    grav       NaN      grav       NaN
# 381        4618  grav  grav    grav       NaN      grav       NaN
# 382        4619  grav  grav    grav       NaN      grav       NaN
# 383        4628  grav  grav    grav       NaN      grav       NaN
# 384        4641  cont  cont    cont       NaN      grav       NaN
# 385        4647  cont  cont    cont       NaN      cont       NaN
# 386        4652  grav  cont    grav       NaN      grav       NaN
# 387        4681  grav  grav    grav       NaN      grav       NaN
# 388        4686  cont  cont    grav       NaN      cont       NaN
# 389        4694  cont  cont    cont       NaN      cont       NaN
# 390        4705  cont  cont    cont       NaN      cont       NaN
# 391        4706  cont  cont    cont       NaN      cont       NaN
# 392        4710  grav  grav    grav       NaN      grav       NaN
# 393        4713  grav  grav    grav       NaN      grav       NaN
# 394        4759  grav  cont    cont       NaN      grav       NaN
# 395        4762  cont  cont    cont       NaN      cont       NaN
# 396        4763  cont  cont    cont       NaN      cont       NaN
# 397        4786  cont  cont    cont       NaN      cont       NaN
# 398        4805  grav  cont    grav       NaN      grav       NaN
# 399        4807  cont  cont    cont       NaN      cont       NaN
# 400        4813  grav  grav    grav       NaN      grav       NaN
# 401        4817  cont  cont    cont       NaN      cont       NaN
# 402        4819  cont  cont    cont       NaN      cont       NaN
# 403        4822  grav  cont    grav       NaN      grav       NaN
# 404        4835  cont  cont    cont       NaN      cont       NaN
# 405        4872  cont  grav    cont       NaN      cont       NaN
# 406        4881  grav  grav    grav       NaN      grav       NaN
# 407        4904  cont  cont    cont       NaN      cont       NaN
# 408        4921  grav  grav    grav       NaN      grav       NaN
# 409        4930  grav  grav    grav       NaN      grav       NaN
# 410        4939  grav  cont    grav       NaN      cont       NaN
# 411        4947  cont  cont    cont       NaN      cont       NaN
# 412        4949  cont  cont    cont       NaN      cont       NaN
# 413        4958  grav  grav    grav       NaN      grav       NaN
# 414        4960  cont  cont    grav       NaN      cont       NaN
# 415        4974  cont  cont    cont       NaN      cont       NaN
# 416        4975  cont  grav    grav       NaN      cont       NaN
# 417        4993  grav  cont    grav       NaN      grav       NaN
# 418        4997  grav  cont    cont       NaN      cont       NaN
# 419        4998  cont  cont    cont       NaN      cont       NaN
# 420        5015  grav  cont    grav       NaN      cont       NaN
# 421        5021  grav  grav    grav       NaN      grav       NaN
# 422        5040  cont  cont    cont       NaN      cont       NaN
# 423        5041  cont  cont    cont       NaN      cont       NaN
# 424        5051  grav  cont    cont       NaN      cont       NaN
# 425        5069  grav  grav    grav       NaN      grav       NaN
# 426        5070  grav  grav    grav       NaN      grav       NaN
# 427        5095  grav  cont    grav       NaN      grav       NaN
# 428        5099  cont  cont    cont       NaN      cont       NaN
# 429        5113  cont  cont    cont       NaN      cont       NaN
# 430        5125  grav  cont    cont       NaN      cont       NaN
# 431        5128  cont  cont    cont       NaN      cont       NaN
# 432        5143  cont  cont    cont       NaN      cont       NaN
# 433        5153  cont  cont    cont       NaN      cont       NaN
# 434        5158  cont  cont    cont       NaN      cont       NaN
# 435        5177  cont  cont    cont       NaN      cont       NaN
# 436        5183  cont  cont    grav       NaN      grav       NaN
# 437        5197  cont  cont    cont       NaN      cont       NaN
# 438        5203  grav  grav    grav       NaN      grav       NaN
# 439        5214  cont  cont    cont       NaN      cont       NaN
# 440        5237  grav  grav    grav       NaN      grav       NaN
# 441        5244  cont  cont    grav       NaN      grav       NaN
# 442        5246  cont  cont    cont       NaN      cont       NaN
# 443        5258  cont  grav    grav       NaN      grav       NaN
# 444        5260  grav  grav    grav       NaN      grav       NaN
# 445        5263  cont  cont    cont       NaN      cont       NaN
# 446        5269  cont  cont    cont       NaN      grav       NaN
# 447        5273  grav  grav    grav       NaN      grav       NaN
# 448        5281  cont  cont    cont       NaN      cont       NaN
# 449        5290  grav  grav    grav       NaN      grav       NaN
# 450        5297  grav  cont    grav       NaN      grav       NaN
# 451        5299  grav  cont    cont       NaN      cont       NaN
# 452        5302  cont  cont    cont       NaN      cont       NaN
# 453        5310  grav  cont    grav       NaN      grav       NaN
# 454        5323  grav  grav    grav       NaN      grav       NaN
# 455        5329  cont  cont    cont       NaN      grav       NaN
# 456        5331  cont  cont    cont       NaN      cont       NaN
# 457        5333  grav  grav    grav       NaN      grav       NaN
# 458        5335  grav  cont    cont       NaN      grav       NaN
# 459        5337  grav  grav    cont       NaN      grav       NaN
# 460        5341  cont  cont    cont       NaN      cont       NaN
# 461        5378  grav  grav    grav       NaN      grav       NaN
# 462        5392  cont  cont    cont       NaN      cont       NaN
# 463        5397  grav  cont    grav       NaN      grav       NaN
# 464        5405  cont  cont    cont       NaN      cont       NaN
# 465        5426  grav  grav    grav       NaN      grav       NaN
# 466        5437  cont  cont    cont       NaN      cont       NaN
# 467        5457  cont  cont    cont       NaN      cont       NaN
# 468        5465  cont  cont    cont       NaN      cont       NaN
# 469        5466  cont  cont    cont       NaN      cont       NaN
# 470        5481  cont  cont    cont       NaN      cont       NaN
# 471        5488  cont  cont    cont       NaN      cont       NaN
# 472        5495  cont  cont    cont       NaN      cont       NaN
# 473        5507  cont  cont    cont       NaN      cont       NaN
# 474        5523  cont  cont    cont       NaN      cont       NaN
# 475        5540  grav  grav    grav       NaN      grav       NaN
# 476        5543  grav  grav    grav       NaN      grav       NaN
# 477        5545  cont  cont    cont       NaN      cont       NaN
# 478        5546  grav  grav    grav       NaN      grav       NaN
# 479        5550  grav  cont    grav       NaN      grav       NaN
# 480        5551  grav  grav    grav       NaN      grav       NaN
# 481        5563  cont  cont    cont       NaN      cont       NaN
# 482        5571  grav  grav    cont       NaN      grav       NaN
# 483        5586  grav  cont    grav       NaN      grav       NaN
# 484        5599  cont  cont    cont       NaN      cont       NaN
# 485        5607  grav  grav    grav       NaN      grav       NaN
# 486        5608  grav  grav    grav       NaN      grav       NaN
# 487        5646  grav  grav    grav       NaN      grav       NaN
# 488        5647  grav  cont    cont       NaN      cont       NaN
# 489        5661  cont  cont    cont       NaN      cont       NaN
# 490        5673  grav  cont    grav       NaN      grav       NaN
# 491        5681  grav  cont    grav       NaN      grav       NaN
# 492        5714  cont  cont    cont       NaN      cont       NaN
# 493        5749  cont  cont    cont       NaN      cont       NaN
# 494        5758  grav  cont    grav       NaN      grav       NaN
# 495        5763  grav  grav    grav       NaN      grav       NaN
# 496        5768  grav  cont    grav       NaN      grav       NaN
# 497        5807  cont  cont    cont       NaN      cont       NaN
# 498        5820  grav  grav    grav       NaN      grav       NaN
# 499        5826  cont  cont    cont       NaN      cont       NaN
# 500        5838  grav  grav    grav       NaN      grav       NaN
# 501        5839  cont  cont    cont       NaN      cont       NaN
# 502        5865  grav  grav    grav       NaN      grav       NaN
# 503        5871  cont  cont    cont       NaN      cont       NaN
# 504        5881  cont  cont    cont       NaN      cont       NaN
# 505        5887  cont  cont    cont       NaN      cont       NaN
# 506        5888  grav  grav    grav       NaN      grav       NaN
# 507        5890  grav  cont    grav       NaN      grav       NaN
# 508        5901  grav  grav    grav       NaN      grav       NaN
# 509        5906  grav  grav    grav       NaN      grav       NaN
# 510        5913  grav  grav    grav       NaN      grav       NaN
# 511        5942  cont  cont    cont       NaN      cont       NaN
# 512        5965  grav  grav    grav       NaN      grav       NaN
# 513        5981  cont  cont    cont       NaN      cont       NaN
# 514        5989  grav  grav    grav       NaN      grav       NaN
# 515        6003  grav  cont    cont       NaN      grav       NaN
# 516        6037  cont  cont    cont       NaN      cont       NaN
# 517        6060  cont  cont    cont       NaN      grav       NaN
# 518        6073  cont  cont    cont       NaN      cont       NaN
# 519        6074  grav  grav    grav       NaN      grav       NaN
# 520        6106  grav  grav    grav       NaN      grav       NaN
# 521        6119  cont  cont    cont       NaN      cont       NaN
# 522        6126  cont  cont    cont       NaN      cont       NaN
# 523        6147  grav  cont    grav       NaN      cont       NaN
# 524        6148  cont  cont    cont       NaN      cont       NaN
# 525        6150  grav  cont    cont       NaN      cont       NaN
# 526        6155  grav  grav    grav       NaN      grav       NaN
# 527        6160  cont  cont    cont       NaN      grav       NaN
# 528        6163  grav  grav    grav       NaN      grav       NaN
# 529        6171  cont  cont    cont       NaN      cont       NaN
# 530        6177  cont  cont    cont       NaN      grav       NaN
# 531        6182  cont  cont    cont       NaN      grav       NaN
# 532        6185  cont  cont    cont       NaN      cont       NaN
# 533        6237  cont  cont    cont       NaN      grav       NaN
# 534        6252  cont  cont    cont       NaN      cont       NaN
# 535        6258  cont  cont    cont       NaN      cont       NaN
# 536        6264  cont  cont    grav       NaN      grav       NaN
# 537        6277  grav  grav    grav       NaN      grav       NaN
# 538        6283  grav  grav    cont       NaN      grav       NaN
# 539        6297  grav  cont    grav       NaN      grav       NaN
# 540        6298  grav  grav    cont       NaN      grav       NaN
# 541        6307  cont  cont    cont       NaN      cont       NaN
# 542        6319  cont  cont    cont       NaN      cont       NaN
# 543        6355  grav  cont    grav       NaN      grav       NaN
# 544        6361  cont  cont    cont       NaN      cont       NaN
# 545        6366  cont  cont    cont       NaN      cont       NaN
# 546        6371  cont  cont    cont       NaN      cont       NaN
# 547        6396  cont  cont    cont       NaN      cont       NaN
# 548        6432  grav  grav    grav       NaN      grav       NaN
# 549        6439  cont  cont    cont       NaN      cont       NaN
# 550        6478  grav  grav    grav       NaN      grav       NaN
# 551        6486  grav  grav    grav       NaN      grav       NaN
# 552        6489  grav  cont    grav       NaN      grav       NaN
# 553        6491  cont  cont    cont       NaN      cont       NaN
# 554        6502  grav  grav    grav       NaN      grav       NaN
# 555        6512  cont  cont    cont       NaN      cont       NaN
# 556        6513  grav  cont    grav       NaN      grav       NaN
# 557        6515  grav  cont    cont       NaN      cont       NaN
# 558        6518  grav  cont    cont       NaN      cont       NaN
# 559        6553  grav  grav    grav       NaN      grav       NaN
# 560        6555  grav  cont    grav       NaN      grav       NaN
# 561        6579  grav  grav    grav       NaN      grav       NaN
# 562        6599  grav  grav    grav       NaN      grav       NaN
# 563        6626  cont  cont    grav       NaN      cont       NaN
# 564        6643  grav  grav    grav       NaN      grav       NaN
# 565        6662  grav  grav    grav       NaN      grav       NaN
# 566        6693  cont  cont    cont       NaN      cont       NaN
# 567        6706  cont  cont    cont       NaN      cont       NaN
# 568        6707  grav  grav    grav       NaN      grav       NaN
# 569        6725  grav  cont    cont       NaN      cont       NaN
# 570        6741  cont  cont    cont       NaN      cont       NaN
# 571        6764  grav  grav    grav       NaN      grav       NaN
# 572        6773  cont  cont    cont       NaN      cont       NaN
# 573        6788  grav  grav    grav       NaN      grav       NaN
# 574        6806  grav  grav    grav       NaN      grav       NaN
# 575        6818  cont  grav    grav       NaN      grav       NaN
# 576        6838  cont  cont    cont       NaN      cont       NaN
# 577        6855  grav  cont    cont       NaN      cont       NaN
# 578        6859  cont  cont    cont       NaN      cont       NaN
# 579        6870  cont  cont    cont       NaN      cont       NaN
# 580        6879  cont  cont    cont       NaN      cont       NaN
# 581        6880  cont  cont    cont       NaN      cont       NaN
# 582        6888  cont  cont    cont       NaN      cont       NaN
# 583        6913  cont  grav    cont       NaN      cont       NaN
# 584        6956  grav  grav    grav       NaN      grav       NaN
# 585        6965  grav  cont    grav       NaN      grav       NaN
# 586        6989  grav  grav    grav       NaN      grav       NaN
# 587        7016  cont  cont    cont       NaN      cont       NaN
# 588        7027  cont  cont    cont       NaN      cont       NaN
# 589        7041  grav  grav    grav       NaN      grav       NaN
# 590        7044  grav  grav    grav       NaN      grav       NaN
# 591        7049  grav  cont    cont       NaN      cont       NaN
# 592        7057  cont  cont    cont       NaN      cont       NaN
# 593        7068  cont  cont    cont       NaN      cont       NaN
# 594        7077  grav  grav    grav       NaN      grav       NaN
# 595        7104  grav  grav    grav       NaN      grav       NaN
# 596        7166  grav  cont    cont       NaN      grav       NaN
# 597        7193  cont  cont    cont       NaN      cont       NaN
# 598        7251  cont  cont    cont       NaN      cont       NaN
# 599        7256  cont  grav    grav       NaN      grav       NaN
# 600        7277  grav  grav    grav       NaN      grav       NaN
# 601        7283  grav  cont    cont       NaN      grav       NaN
# 602        7290  grav  cont    cont       NaN      grav       NaN
# 603        7291  grav  grav    grav       NaN      grav       NaN
# 604        7295  grav  cont    grav       NaN      grav       NaN
# 605        7302  grav  cont    cont       NaN      grav       NaN
# 606        7346  grav  grav    grav       NaN      grav       NaN
# 607        7349  grav  grav    grav       NaN      grav       NaN
# 608        7400  cont  cont    cont       NaN      cont       NaN
# 609        7402  cont  cont    cont       NaN      cont       NaN
# 610        7403  grav  cont    grav       NaN      grav       NaN
# 611        7419  grav  grav    grav       NaN      grav       NaN
# 612        7424  cont  cont    cont       NaN      cont       NaN
# 613        7428  grav  grav    grav       NaN      grav       NaN
# 614        7436  grav  grav    grav       NaN      grav       NaN
# 615        7443  grav  grav    grav       NaN      grav       NaN
# 616        7449  grav  grav    grav       NaN      grav       NaN
# 617        7455  grav  grav    grav       NaN      grav       NaN
# 618        7466  cont  cont    cont       NaN      cont       NaN
# 619        7487  cont  cont    grav       NaN      cont       NaN
# 620        7511  cont  cont    cont       NaN      cont       NaN
# 621        7527  grav  grav    grav       NaN      grav       NaN
# 622        7534  grav  grav    grav       NaN      grav       NaN
# 623        7552  grav  grav    grav       NaN      grav       NaN
# 624        7583  cont  cont    cont       NaN      cont       NaN
# 625        7594  cont  cont    cont       NaN      cont       NaN
# 626        7644  grav  cont    grav       NaN      grav       NaN
# 627        7669  grav  cont    cont       NaN      cont       NaN
# 628        7681  grav  grav    grav       NaN      grav       NaN
# 629        7691  cont  cont    cont       NaN      cont       NaN
# 630        7709  grav  grav    grav       NaN      grav       NaN
# 631        7726  cont  cont    cont       NaN      cont       NaN
# 632        7738  cont  cont    cont       NaN      cont       NaN
# 633        7740  cont  cont    cont       NaN      cont       NaN
# 634        7741  cont  cont    cont       NaN      cont       NaN
# 635        7745  grav  grav    grav       NaN      grav       NaN
# 636        7763  grav  cont    grav       NaN      grav       NaN
# 637        7765  grav  grav    grav       NaN      grav       NaN
# 638        7781  grav  cont    grav       NaN      grav       NaN
# 639        7795  cont  cont    cont       NaN      cont       NaN
# 640        7798  grav  cont    grav       NaN      grav       NaN
# 641        7800  grav  grav    grav       NaN      grav       NaN
# 642        7808  cont  cont    cont       NaN      cont       NaN
# 643        7813  cont  cont    cont       NaN      cont       NaN
# 644        7867  grav  grav    grav       NaN      grav       NaN
# 645        7868  cont  cont    cont       NaN      cont       NaN
# 646        7874  grav  grav    grav       NaN      grav       NaN
# 647        7879  grav  cont    grav       NaN      grav       NaN
# 648        7900  grav  cont    grav       NaN      grav       NaN
# 649        7905  cont  cont    cont       NaN      cont       NaN
# 650        7936  grav  grav    grav       NaN      grav       NaN
# 651        7960  cont  cont    cont       NaN      cont       NaN
# 652        7963  cont  cont    cont       NaN      cont       NaN
# 653        7985  cont  cont    cont       NaN      cont       NaN
# 654        8002  cont  cont    cont       NaN      cont       NaN
# 655        8019  cont  cont    cont       NaN      cont       NaN
# 656        8027  cont  cont    cont       NaN      cont       NaN
# 657        8040  cont  cont    cont       NaN      grav       NaN
# 658        8079  grav  grav    grav       NaN      grav       NaN
# 659        8088  cont  cont    cont       NaN      cont       NaN
# 660        8120  cont  cont    cont       NaN      cont       NaN
# 661        8149  cont  cont    cont       NaN      cont       NaN
# 662        8168  grav  grav    grav       NaN      grav       NaN
# 663        8184  grav  cont    grav       NaN      grav       NaN
# 664        8198  grav  grav    grav       NaN      grav       NaN
# 665        8210  cont  cont    cont       NaN      cont       NaN

# %%
def transpose_value(df1, df2, col1, col2):
    k=0
    for i in range(len(df1)):
        img_num = df1.iloc[k,0]  #CSV1つ目の画像番号を取得
        pred = df2[df2['image_name'] == img_num].iloc[0,col2]   #この画像番号に対応する２つ目CSVの行（の●列目）の値を取得
        df1.iloc[k, col1] = pred #CSV1つ目の所定の場所に代入
        k+=1
    return df1

#1つ目CSVと2つ目CSVとの列対応を入力
col1, col2 = 3, 5 #kitaguchi
df1 = transpose_value(df1, df2, col1, col2)
col1, col2 = 4, 2 #inoue
df1 = transpose_value(df1, df2, col1, col2)
col1, col2 = 5, 3 #kohzaki
df1 = transpose_value(df1, df2, col1, col2)

print(df1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-ab923b7dd8b5> in <module>()
#      10 #1つ目CSVと2つ目CSVとの列対応を入力
#      11 col1, col2 = 3, 5 #kitaguchi
# ---> 12 df1 = transpose_value(df1, df2, col1, col2)
#      13 col1, col2 = 4, 2 #inoue
#      14 df1 = transpose_value(df1, df2, col1, col2)
#
# <ipython-input-12-ab923b7dd8b5> in transpose_value(df1, df2, col1, col2)
#       1 def transpose_value(df1, df2, col1, col2):
#       2     k=0
# ----> 3     for i in range(len(df)):
#       4         img_num = df1.iloc[k,0]  #CSV1つ目の画像番号を取得
#       5         pred = df2[df2['image_name'] == img_num].iloc[0,col2]   #この画像番号に対応する２つ目CSVの行（の●列目）の値を取得
#
# NameError: name 'df' is not defined

# %% [markdown]
# #**CSVとして保存**

# %%
csv_path = '/content/drive/My Drive/Grav_bootcamp/Posttrain_result.csv'
csv = df1.to_csv(csv_path)
